# %% [markdown]
# <a href="https://colab.research.google.com/github/prosperjohn9/DNASequence/blob/main/DNAsequence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhiteBoard-11_10_2023-12_04_29 AM.png](data:image/png;base64,...)

# %%
# Obtain the DNA sequence from the user
DNA_sequence = input("Please enter a DNA Sequence: ")

# Control variable(we assume that the user will enter a valid DNA sequence)
isCorrect = True

# Check validity of the input sequence
for dna in DNA_sequence:
  # Check if that particular letter is not one of those valid characters
  if (dna != "a" and dna != "c" and dna != "g" and dna != "t") and \
     (dna != "A" and dna != "C" and dna != "G" and dna != "T"):
     # If it is an invalid character, update the control variable
     isCorrect = False
     break

# Check the control variable to decide on whether the input is valid or not
if not isCorrect:
  print("This is not a correct DNA Sequence.")
else:
  print("This is a correct DNA Sequence.")
# Out:
# Please enter a DNA Sequence: trdfg
# This is not a correct DNA Sequence.
